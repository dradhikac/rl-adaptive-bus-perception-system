# %%
import cv2
import matplotlib.pyplot as plt
import os

image_folder = "../datasets/bdd100k/images"

images = os.listdir(image_folder)

image_path = os.path.join(image_folder, images[0])

image = cv2.imread(image_path)

# Convert BGR to RGB
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image)
plt.title("BDD100K Sample Image")
plt.axis("off")

plt.show()

# %%
brightness_values = [20, 40, 60, 80, 100]

labels = ["Night", "Fog", "Cloudy", "Evening", "Sunny"]

plt.bar(labels, brightness_values)

plt.title("Environmental Brightness Levels")

plt.xlabel("Condition")
plt.ylabel("Brightness")

plt.show()

# %%
feature_names = ["Blur", "Brightness", "Edges", "Contrast"]
feature_names = ["Blur", "Brightness", "Edges", "Contrast"]

blur_score = 687.1957479368422
edge_count = 22343
brightness = 107.71146809895833
contrast = 62.58211346522562

feature_values = [
    blur_score,
    brightness,
    edge_count / 1000,
    contrast
]

import matplotlib.pyplot as plt

feature_names = ["Blur", "Brightness", "Edges", "Contrast"]
feature_names = ["Blur", "Brightness", "Edges", "Contrast"]

blur_score = 687.1957479368422
edge_count = 22343
brightness = 107.71146809895833
contrast = 62.58211346522562

feature_values = [
    blur_score,
    brightness,
    edge_count / 1000,
    contrast
]

plt.figure(figsize=(8,5))

plt.bar(feature_names, feature_values)

plt.title("Vision Feature Analysis")

plt.ylabel("Feature Value")

plt.show()
